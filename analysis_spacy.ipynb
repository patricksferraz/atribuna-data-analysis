# %%
from nltk.stem.snowball import SnowballStemmer # spaCy doesn't contain
from spellchecker import SpellChecker
from textblob import TextBlob
import unicodedata
import inflect
import spacy
import os
import re

# %% [markdown]
# ---

# %% [markdown]
# ## Global variables

# %%
# Set spacy and stem for Portuguese Language
nlp = spacy.load("pt")
stemmer = SnowballStemmer(language='portuguese')

# %%
# Variables for usage
REGEX = {
    "end_punc": r"(\w)",
    "all_punc": r""
}

ARGS = {
    "dataset": "dataset"
}

# List all txt files of folder
files = os.listdir(ARGS["dataset"])

# %% [markdown]
# ---

# %% [markdown]
# ## Functions

# %%
def _all2ascii(tokens):
    def _removes(token):
        token = unicodedata.normalize('NFKD', token)
        return token.encode('ascii', 'ignore').decode('utf-8', 'ignore')

    return [_removes(_) for _ in tokens]

# %%
def _all2lower(tokens):
    return [_.lower() for _ in tokens]

# %%
def _changes_punctuation(tokens):
    return [re.sub(r"[^\w\s]", "", _) for _ in tokens]

# %%
def _numbers2words(tokens):
    inf = inflect.engine()
    return [inf.number_to_words(_) if _.isdigit() else _ for _ in tokens]

# %%
def normalize(tokens):
    tokens = _all2ascii(tokens)
    tokens = _all2lower(tokens)
    tokens = _changes_punctuation(tokens)
    tokens = _numbers2words(tokens)
    return tokens

# %% [markdown]
# ---

# %%
# Read and decode the text
file = open(f'{ARGS["dataset"]}/{files[0]}', "rb")
text = file.read().decode('latin-1')
print(text)
# Out:
# Eternamente criança
# <b> A mais recente versão para o cinema da história de Peter Pan pretende ser tão assustadora quanto fascinante   </b><br>
# DÉBORA VICENTINI <br>
# Ahistória do menino que não queria crescer sempre fascinou adultos e crianças no mundo inteiro. Agora, esses fãs poderão conferir mais uma versão dessa história mágica com o filme Peter Pan, que estréia hoje nos cinemas capixabas. Quem acha que Peter Pan não é nada mais do que uma fantasia infantil sobre crocodilos simpáticos, fadinhas voadoras, vilões bigodudos e piratas com ganchos no lugar de mãos deve repensar suas posições com essa nova versão, que tem roteiro e direção de P.J. Hogan (O Casamento de Muriel). A mais recente versão para o cinema da história criada há 100 anos pelo britânico J. M. Barrie sobre um garoto que se recusa a crescer pretende ser tão assustadora quanto fascinante e, além disso, agradar a todas as idades. O novo Peter Pan é a primeira versão moderna da história filmada com personagens de verdade  o angelical Jeremy Sumpter, de 14 anos, faz o papel-título. O capitão Gancho é representado por Jason Isaacs como uma figura assustadora, sem aquela menção cômica das versões anteriores. O mesmo ator também faz o papel do pai de Wendy Darling, representada pela desconhecida atriz britânica Rachel Hurd-Wood, de 13 anos. Wendy é uma uma garota que reluta em deixar de ser criança e que se apaixona pela primeira vez. O Peter Pan criado por Hogan tem vários momentos assustadores. As sereias da Terra do Nunca que tentam atrair Wendy para a morte rápida pelo afogamento têm tão pouca semelhança com a Pequena Sereia da Disney quando o capitão Gancho tem com um pai amoroso. O próprio capitão Gancho, que em muitas versões da história é apresentado como figura caricata, é um louco narcisista que sen- te prazer em escolher entre os diversos ganchos de metal aquele que usará a cada dia.
#  SERVIÇO
#   Filme: Peter Pan  Gênero: aventura  Censura: livre  Direção: J. P. Hogan  Elenco: Jeremy Sumpter, Jason Isaacs  Onde ver: Kinoplex 5, Multiplex Laranjeiras 3, Viva Cinema 1
#  SAIBA MAIS
#  Jeremy Sumpter (de A Mão do Diabo) é o único ator americano no elenco de protagonistas do filme.  Jason Isaacs já fez trabalhos como O Patriota, Falcão Negro em Perigo e Harry Potter e a Câmara Secreta.  O diretor P.J.Hogan co-escreveu Peter Pan com Michael Goldenberg, de Contato.  O filme foi rodado na Austrália.  Hogan trabalhou nos bastidores com cineastas australianos como o diretor de fotografia Donald McAlpine, indicado ao Oscar com Moulin Rouge; o desenhista de produção Roger Ford, indicado ao Oscar com Babe, e Janet Patterson, indicada ao Oscar com O Piano, Retrato de uma Mulher e Oscar e Lucinda.
#  <br><br><hr>
# Data da Publicação: 09/01/2004 - Pagina: 3 <br>
# Editoria: At2 <br><br>

# %%
# spelling correction
# text = TextBlob(text)
# text.detect_language()

# %%
# initial text
idoc = nlp(text)

# %%
# split the text
text = text.split()

# %%
# spelling correction
# spell = SpellChecker()

# # find those words that may be misspelled
# misspelled = spell.unknown(text)
# print(misspelled)

# for word in misspelled:
#     # Get the one `most likely` answer
#     print(spell.correction(word))

#     # Get a list of `likely` options
#     print(spell.candidates(word))

# %% [markdown]
# ### Preprocess
#
# **doc:** ents, sents <br>
# **tokens:** text, lemma_, pos_, tag_, dep_, shape_, is_alpha, is_stop, start_char, end_char, label_, ent_iob_, ent_type_

# %%
# normalization
text = _all2ascii(text) # convert all text for ascii
text = _all2lower(text) # convert all text for lower case
text = _changes_punctuation(text) # changes punctuations for blank
text = _numbers2words(text) # convert all digits for words

# initializing
tokens = nlp(" ".join(text))

# print(text)

# %%
# Another method for see normalization params
# tokens = [_ for _ in doc]
# Convert to lower
# [_.lower_ for _ in tokens]
# Getting only words in the text
# [_.orth_ for _ in tokens if not _.is_punct]
# strings in each token
# [_.orth_ for _ in tokens]

# %% [markdown]
# ---

# %% [markdown]
# ### Process

# %%
# Removes Stop words
# nlp.Defaults.stop_words
[_ for _ in tokens if not _.is_stop]
# Out:
# [eternamente,
#  crianca,
#  b,
#  a,
#  recente,
#  versao,
#  o,
#  cinema,
#  historia,
#  peter,
#  pan,
#  pretende,
#  tao,
#  assustadora,
#  fascinante,
#  bbr,
#  debora,
#  vicentini,
#  br,
#  ahistoria,
#  menino,
#  nao,
#  queria,
#  crescer,
#  fascinou,
#  adultos,
#  e,
#  criancas,
#  mundo,
#  inteiro,
#  fas,
#  poderao,
#  conferir,
#  versao,
#  d,
#  historia,
#  magica,
#  o,
#  filme,
#  peter,
#  pan,
#  estreia,
#  cinemas,
#  capixabas,
#  acha,
#  peter,
#  pan,
#  nao,
#  e,
#  fantasia,
#  infantil,
#  crocodilos,
#  simpaticos,
#  fadinhas,
#  voadoras,
#  viloes,
#  bigodudos,
#  e,
#  piratas,
#  ganchos,
#  maos,
#  repensar,
#  posicoes,
#  versao,
#  roteiro,
#  e,
#  direcao,
#  pj,
#  hogan,
#  o,
#  casamento,
#  muriel,
#  a,
#  recente,
#  versao,
#  o,
#  cinema,
#  historia,
#  criada,
#  ha,
#  one,
#  hundred,
#  britanico,
#  j,
#  m,
#  barrie,
#  garoto,
#  recusa,
#  a,
#  crescer,
#  pretende,
#  tao,
#  assustadora,
#  fascinante,
#  e,
#  alem,
#  d,
#  agradar,
#  a,
#  idades,
#  o,
#  peter,
#  pan,
#  e,
#  a,
#  versao,
#  moderna,
#  historia,
#  filmada,
#  personagens,
#   ,
#  o,
#  angelical,
#  jeremy,
#  sumpter,
#  fourteen,
#  o,
#  papeltitulo,
#  o,
#  capitao,
#  gancho,
#  e,
#  representado,
#  jason,
#  isaacs,
#  figura,
#  assustadora,
#  mencao,
#  comica,
#  versoes,
#  anteriores,
#  o,
#  ator,
#  tambem,
#  o,
#  papel,
#  pai,
#  wendy,
#  darling,
#  representada,
#  desconhecida,
#  atriz,
#  britanica,
#  rachel,
#  hurdwood,
#  thirteen,
#  wendy,
#  e,
#  garota,
#  reluta,
#  deixar,
#  crianca,
#  e,
#  apaixona,
#  o,
#  peter,
#  pan,
#  criado,
#  hogan,
#  varios,
#  momentos,
#  assustadores,
#  sereias,
#  terra,
#  tentam,
#  atrair,
#  wendy,
#  a,
#  morte,
#  rapida,
#  afogamento,
#  tao,
#  semelhanca,
#  a,
#  pequena,
#  sereia,
#  disney,
#  o,
#  capitao,
#  gancho,
#  pai,
#  amoroso,
#  o,
#  proprio,
#  capitao,
#  gancho,
#  muitas,
#  versoes,
#  historia,
#  e,
#  apresentado,
#  figura,
#  caricata,
#  e,
#  louco,
#  narcisista,
#  sen,
#  prazer,
#  escolher,
#  diversos,
#  ganchos,
#  metal,
#  usara,
#  a,
#  servico,
#   ,
#  filme,
#  peter,
#  pan,
#   ,
#  genero,
#  aventura,
#   ,
#  censura,
#  livre,
#   ,
#  direcao,
#  j,
#  p,
#  hogan,
#   ,
#  elenco,
#  jeremy,
#  sumpter,
#  jason,
#  isaacs,
#   ,
#  kinoplex,
#  five,
#  multiplex,
#  laranjeiras,
#  three,
#  viva,
#  cinema,
#  one,
#  saiba,
#   ,
#  jeremy,
#  sumpter,
#  a,
#  mao,
#  diabo,
#  e,
#  o,
#  unico,
#  ator,
#  americano,
#  elenco,
#  protagonistas,
#  filme,
#   ,
#  jason,
#  isaacs,
#  ja,
#  trabalhos,
#  o,
#  patriota,
#  falcao,
#  negro,
#  perigo,
#  e,
#  harry,
#  potter,
#  e,
#  a,
#  camara,
#  secreta,
#   ,
#  o,
#  diretor,
#  pjhogan,
#  coescreveu,
#  peter,
#  pan,
#  michael,
#  goldenberg,
#  contato,
#   ,
#  o,
#  filme,
#  rodado,
#  australia,
#   ,
#  hogan,
#  trabalhou,
#  bastidores,
#  cineastas,
#  australianos,
#  o,
#  diretor,
#  fotografia,
#  donald,
#  mcalpine,
#  indicado,
#  a,
#  o,
#  oscar,
#  moulin,
#  rouge,
#  o,
#  desenhista,
#  producao,
#  roger,
#  ford,
#  indicado,
#  a,
#  o,
#  oscar,
#  babe,
#  e,
#  janet,
#  patterson,
#  indicada,
#  a,
#  o,
#  oscar,
#  o,
#  piano,
#  retrato,
#  mulher,
#  e,
#  oscar,
#  e,
#  lucinda,
#  brbrhr,
#  data,
#  publicacao,
#  nine,
#  million,
#  ,,
#  twelve,
#  thousand,
#  and,
#  four,
#   ,
#  pagina,
#  three,
#  br,
#  editoria,
#  at2,
#  brbr]

# %%
# Stemming
[(_.orth_, stemmer.stem(_.orth_)) for _ in tokens]
# Out:
# [('eternamente', 'etern'),
#  ('crianca', 'crianc'),
#  ('b', 'b'),
#  ('a', 'a'),
#  ('mais', 'mais'),
#  ('recente', 'recent'),
#  ('versao', 'versa'),
#  ('para', 'par'),
#  ('o', 'o'),
#  ('cinema', 'cinem'),
#  ('da', 'da'),
#  ('historia', 'histor'),
#  ('de', 'de'),
#  ('peter', 'pet'),
#  ('pan', 'pan'),
#  ('pretende', 'pretend'),
#  ('ser', 'ser'),
#  ('tao', 'tao'),
#  ('assustadora', 'assust'),
#  ('quanto', 'quant'),
#  ('fascinante', 'fascin'),
#  ('bbr', 'bbr'),
#  ('debora', 'debor'),
#  ('vicentini', 'vicentin'),
#  ('br', 'br'),
#  ('ahistoria', 'ahistor'),
#  ('do', 'do'),
#  ('menino', 'menin'),
#  ('que', 'que'),
#  ('nao', 'nao'),
#  ('queria', 'quer'),
#  ('crescer', 'cresc'),
#  ('sempre', 'sempr'),
#  ('fascinou', 'fascin'),
#  ('adultos', 'adult'),
#  ('e', 'e'),
#  ('criancas', 'crianc'),
#  ('no', 'no'),
#  ('mundo', 'mund'),
#  ('inteiro', 'inteir'),
#  ('agora', 'agor'),
#  ('esses', 'esses'),
#  ('fas', 'fas'),
#  ('poderao', 'podera'),
#  ('conferir', 'confer'),
#  ('mais', 'mais'),
#  ('uma', 'uma'),
#  ('versao', 'versa'),
#  ('d', 'd'),
#  ('essa', 'essa'),
#  ('historia', 'histor'),
#  ('magica', 'magic'),
#  ('com', 'com'),
#  ('o', 'o'),
#  ('filme', 'film'),
#  ('peter', 'pet'),
#  ('pan', 'pan'),
#  ('que', 'que'),
#  ('estreia', 'estre'),
#  ('hoje', 'hoj'),
#  ('nos', 'nos'),
#  ('cinemas', 'cinem'),
#  ('capixabas', 'capixab'),
#  ('quem', 'quem'),
#  ('acha', 'acha'),
#  ('que', 'que'),
#  ('peter', 'pet'),
#  ('pan', 'pan'),
#  ('nao', 'nao'),
#  ('e', 'e'),
#  ('nada', 'nad'),
#  ('mais', 'mais'),
#  ('do', 'do'),
#  ('que', 'que'),
#  ('uma', 'uma'),
#  ('fantasia', 'fantas'),
#  ('infantil', 'infantil'),
#  ('sobre', 'sobr'),
#  ('crocodilos', 'crocodil'),
#  ('simpaticos', 'simpat'),
#  ('fadinhas', 'fadinh'),
#  ('voadoras', 'voador'),
#  ('viloes', 'vilo'),
#  ('bigodudos', 'bigodud'),
#  ('e', 'e'),
#  ('piratas', 'pirat'),
#  ('com', 'com'),
#  ('ganchos', 'ganch'),
#  ('no', 'no'),
#  ('lugar', 'lug'),
#  ('de', 'de'),
#  ('maos', 'maos'),
#  ('deve', 'dev'),
#  ('repensar', 'repens'),
#  ('suas', 'suas'),
#  ('posicoes', 'posico'),
#  ('com', 'com'),
#  ('essa', 'essa'),
#  ('nova', 'nov'),
#  ('versao', 'versa'),
#  ('que', 'que'),
#  ('tem', 'tem'),
#  ('roteiro', 'roteir'),
#  ('e', 'e'),
#  ('direcao', 'direca'),
#  ('de', 'de'),
#  ('pj', 'pj'),
#  ('hogan', 'hogan'),
#  ('o', 'o'),
#  ('casamento', 'casament'),
#  ('de', 'de'),
#  ('muriel', 'muriel'),
#  ('a', 'a'),
#  ('mais', 'mais'),
#  ('recente', 'recent'),
#  ('versao', 'versa'),
#  ('para', 'par'),
#  ('o', 'o'),
#  ('cinema', 'cinem'),
#  ('da', 'da'),
#  ('historia', 'histor'),
#  ('criada', 'cri'),
#  ('ha', 'ha'),
#  ('one', 'one'),
#  ('hundred', 'hundred'),
#  ('anos', 'anos'),
#  ('pelo', 'pel'),
#  ('britanico', 'britan'),
#  ('j', 'j'),
#  ('m', 'm'),
#  ('barrie', 'barri'),
#  ('sobre', 'sobr'),
#  ('um', 'um'),
#  ('garoto', 'garot'),
#  ('que', 'que'),
#  ('se', 'se'),
#  ('recusa', 'recus'),
#  ('a', 'a'),
#  ('crescer', 'cresc'),
#  ('pretende', 'pretend'),
#  ('ser', 'ser'),
#  ('tao', 'tao'),
#  ('assustadora', 'assust'),
#  ('quanto', 'quant'),
#  ('fascinante', 'fascin'),
#  ('e', 'e'),
#  ('alem', 'alem'),
#  ('d', 'd'),
#  ('isso', 'isso'),
#  ('agradar', 'agrad'),
#  ('a', 'a'),
#  ('todas', 'tod'),
#  ('as', 'as'),
#  ('idades', 'idad'),
#  ('o', 'o'),
#  ('novo', 'nov'),
#  ('peter', 'pet'),
#  ('pan', 'pan'),
#  ('e', 'e'),
#  ('a', 'a'),
#  ('primeira', 'primeir'),
#  ('versao', 'versa'),
#  ('moderna', 'modern'),
#  ('da', 'da'),
#  ('historia', 'histor'),
#  ('filmada', 'film'),
#  ('com', 'com'),
#  ('personagens', 'personagens'),
#  ('de', 'de'),
#  ('verdade', 'verdad'),
#  (' ', ' '),
#  ('o', 'o'),
#  ('angelical', 'angelical'),
#  ('jeremy', 'jeremy'),
#  ('sumpter', 'sumpt'),
#  ('de', 'de'),
#  ('fourteen', 'fourteen'),
#  ('anos', 'anos'),
#  ('faz', 'faz'),
#  ('o', 'o'),
#  ('papeltitulo', 'papeltitul'),
#  ('o', 'o'),
#  ('capitao', 'capita'),
#  ('gancho', 'ganch'),
#  ('e', 'e'),
#  ('representado', 'represent'),
#  ('por', 'por'),
#  ('jason', 'jason'),
#  ('isaacs', 'isaacs'),
#  ('como', 'com'),
#  ('uma', 'uma'),
#  ('figura', 'figur'),
#  ('assustadora', 'assust'),
#  ('sem', 'sem'),
#  ('aquela', 'aquel'),
#  ('mencao', 'menca'),
#  ('comica', 'comic'),
#  ('das', 'das'),
#  ('versoes', 'verso'),
#  ('anteriores', 'anterior'),
#  ('o', 'o'),
#  ('mesmo', 'mesm'),
#  ('ator', 'ator'),
#  ('tambem', 'tamb'),
#  ('faz', 'faz'),
#  ('o', 'o'),
#  ('papel', 'papel'),
#  ('do', 'do'),
#  ('pai', 'pai'),
#  ('de', 'de'),
#  ('wendy', 'wendy'),
#  ('darling', 'darling'),
#  ('representada', 'represent'),
#  ('pela', 'pel'),
#  ('desconhecida', 'desconhec'),
#  ('atriz', 'atriz'),
#  ('britanica', 'britan'),
#  ('rachel', 'rachel'),
#  ('hurdwood', 'hurdwood'),
#  ('de', 'de'),
#  ('thirteen', 'thirteen'),
#  ('anos', 'anos'),
#  ('wendy', 'wendy'),
#  ('e', 'e'),
#  ('uma', 'uma'),
#  ('uma', 'uma'),
#  ('garota', 'garot'),
#  ('que', 'que'),
#  ('reluta', 'relut'),
#  ('em', 'em'),
#  ('deixar', 'deix'),
#  ('de', 'de'),
#  ('ser', 'ser'),
#  ('crianca', 'crianc'),
#  ('e', 'e'),
#  ('que', 'que'),
#  ('se', 'se'),
#  ('apaixona', 'apaixon'),
#  ('pela', 'pel'),
#  ('primeira', 'primeir'),
#  ('vez', 'vez'),
#  ('o', 'o'),
#  ('peter', 'pet'),
#  ('pan', 'pan'),
#  ('criado', 'cri'),
#  ('por', 'por'),
#  ('hogan', 'hogan'),
#  ('tem', 'tem'),
#  ('varios', 'vari'),
#  ('momentos', 'moment'),
#  ('assustadores', 'assust'),
#  ('as', 'as'),
#  ('sereias', 'ser'),
#  ('da', 'da'),
#  ('terra', 'terr'),
#  ('do', 'do'),
#  ('nunca', 'nunc'),
#  ('que', 'que'),
#  ('tentam', 'tent'),
#  ('atrair', 'atra'),
#  ('wendy', 'wendy'),
#  ('para', 'par'),
#  ('a', 'a'),
#  ('morte', 'mort'),
#  ('rapida', 'rap'),
#  ('pelo', 'pel'),
#  ('afogamento', 'afog'),
#  ('tem', 'tem'),
#  ('tao', 'tao'),
#  ('pouca', 'pouc'),
#  ('semelhanca', 'semelhanc'),
#  ('com', 'com'),
#  ('a', 'a'),
#  ('pequena', 'pequen'),
#  ('sereia', 'ser'),
#  ('da', 'da'),
#  ('disney', 'disney'),
#  ('quando', 'quand'),
#  ('o', 'o'),
#  ('capitao', 'capita'),
#  ('gancho', 'ganch'),
#  ('tem', 'tem'),
#  ('com', 'com'),
#  ('um', 'um'),
#  ('pai', 'pai'),
#  ('amoroso', 'amor'),
#  ('o', 'o'),
#  ('proprio', 'propri'),
#  ('capitao', 'capita'),
#  ('gancho', 'ganch'),
#  ('que', 'que'),
#  ('em', 'em'),
#  ('muitas', 'muit'),
#  ('versoes', 'verso'),
#  ('da', 'da'),
#  ('historia', 'histor'),
#  ('e', 'e'),
#  ('apresentado', 'apresent'),
#  ('como', 'com'),
#  ('figura', 'figur'),
#  ('caricata', 'caricat'),
#  ('e', 'e'),
#  ('um', 'um'),
#  ('louco', 'louc'),
#  ('narcisista', 'narcis'),
#  ('que', 'que'),
#  ('sen', 'sen'),
#  ('te', 'te'),
#  ('prazer', 'praz'),
#  ('em', 'em'),
#  ('escolher', 'escolh'),
#  ('entre', 'entre'),
#  ('os', 'os'),
#  ('diversos', 'divers'),
#  ('ganchos', 'ganch'),
#  ('de', 'de'),
#  ('metal', 'metal'),
#  ('aquele', 'aquel'),
#  ('que', 'que'),
#  ('usara', 'usar'),
#  ('a', 'a'),
#  ('cada', 'cad'),
#  ('dia', 'dia'),
#  ('servico', 'servic'),
#  (' ', ' '),
#  ('filme', 'film'),
#  ('peter', 'pet'),
#  ('pan', 'pan'),
#  (' ', ' '),
#  ('genero', 'gener'),
#  ('aventura', 'aventur'),
#  (' ', ' '),
#  ('censura', 'censur'),
#  ('livre', 'livr'),
#  (' ', ' '),
#  ('direcao', 'direca'),
#  ('j', 'j'),
#  ('p', 'p'),
#  ('hogan', 'hogan'),
#  (' ', ' '),
#  ('elenco', 'elenc'),
#  ('jeremy', 'jeremy'),
#  ('sumpter', 'sumpt'),
#  ('jason', 'jason'),
#  ('isaacs', 'isaacs'),
#  (' ', ' '),
#  ('onde', 'onde'),
#  ('ver', 'ver'),
#  ('kinoplex', 'kinoplex'),
#  ('five', 'fiv'),
#  ('multiplex', 'multiplex'),
#  ('laranjeiras', 'laranjeir'),
#  ('three', 'thre'),
#  ('viva', 'viv'),
#  ('cinema', 'cinem'),
#  ('one', 'one'),
#  ('saiba', 'saib'),
#  ('mais', 'mais'),
#  (' ', ' '),
#  ('jeremy', 'jeremy'),
#  ('sumpter', 'sumpt'),
#  ('de', 'de'),
#  ('a', 'a'),
#  ('mao', 'mao'),
#  ('do', 'do'),
#  ('diabo', 'diab'),
#  ('e', 'e'),
#  ('o', 'o'),
#  ('unico', 'unic'),
#  ('ator', 'ator'),
#  ('americano', 'american'),
#  ('no', 'no'),
#  ('elenco', 'elenc'),
#  ('de', 'de'),
#  ('protagonistas', 'protagon'),
#  ('do', 'do'),
#  ('filme', 'film'),
#  (' ', ' '),
#  ('jason', 'jason'),
#  ('isaacs', 'isaacs'),
#  ('ja', 'ja'),
#  ('fez', 'fez'),
#  ('trabalhos', 'trabalh'),
#  ('como', 'com'),
#  ('o', 'o'),
#  ('patriota', 'patriot'),
#  ('falcao', 'falca'),
#  ('negro', 'negr'),
#  ('em', 'em'),
#  ('perigo', 'perig'),
#  ('e', 'e'),
#  ('harry', 'harry'),
#  ('potter', 'pott'),
#  ('e', 'e'),
#  ('a', 'a'),
#  ('camara', 'cam'),
#  ('secreta', 'secret'),
#  (' ', ' '),
#  ('o', 'o'),
#  ('diretor', 'diretor'),
#  ('pjhogan', 'pjhogan'),
#  ('coescreveu', 'coescrev'),
#  ('peter', 'pet'),
#  ('pan', 'pan'),
#  ('com', 'com'),
#  ('michael', 'michael'),
#  ('goldenberg', 'goldenberg'),
#  ('de', 'de'),
#  ('contato', 'contat'),
#  (' ', ' '),
#  ('o', 'o'),
#  ('filme', 'film'),
#  ('foi', 'foi'),
#  ('rodado', 'rod'),
#  ('na', 'na'),
#  ('australia', 'austral'),
#  (' ', ' '),
#  ('hogan', 'hogan'),
#  ('trabalhou', 'trabalh'),
#  ('nos', 'nos'),
#  ('bastidores', 'bastidor'),
#  ('com', 'com'),
#  ('cineastas', 'cineast'),
#  ('australianos', 'australian'),
#  ('como', 'com'),
#  ('o', 'o'),
#  ('diretor', 'diretor'),
#  ('de', 'de'),
#  ('fotografia', 'fotograf'),
#  ('donald', 'donald'),
#  ('mcalpine', 'mcalpin'),
#  ('indicado', 'indic'),
#  ('a', 'a'),
#  ('o', 'o'),
#  ('oscar', 'oscar'),
#  ('com', 'com'),
#  ('moulin', 'moulin'),
#  ('rouge', 'roug'),
#  ('o', 'o'),
#  ('desenhista', 'desenh'),
#  ('de', 'de'),
#  ('producao', 'produca'),
#  ('roger', 'rog'),
#  ('ford', 'ford'),
#  ('indicado', 'indic'),
#  ('a', 'a'),
#  ('o', 'o'),
#  ('oscar', 'oscar'),
#  ('com', 'com'),
#  ('babe', 'bab'),
#  ('e', 'e'),
#  ('janet', 'janet'),
#  ('patterson', 'patterson'),
#  ('indicada', 'indic'),
#  ('a', 'a'),
#  ('o', 'o'),
#  ('oscar', 'oscar'),
#  ('com', 'com'),
#  ('o', 'o'),
#  ('piano', 'pian'),
#  ('retrato', 'retrat'),
#  ('de', 'de'),
#  ('uma', 'uma'),
#  ('mulher', 'mulh'),
#  ('e', 'e'),
#  ('oscar', 'oscar'),
#  ('e', 'e'),
#  ('lucinda', 'lucind'),
#  ('brbrhr', 'brbrhr'),
#  ('data', 'dat'),
#  ('da', 'da'),
#  ('publicacao', 'publicaca'),
#  ('nine', 'nin'),
#  ('million', 'million'),
#  (',', ','),
#  ('twelve', 'twelv'),
#  ('thousand', 'thousand'),
#  ('and', 'and'),
#  ('four', 'four'),
#  (' ', ' '),
#  ('pagina', 'pagin'),
#  ('three', 'thre'),
#  ('br', 'br'),
#  ('editoria', 'editor'),
#  ('at2', 'at2'),
#  ('brbr', 'brbr')]

# %%
# Lemmatization
# aux = nlp(u"encontrei, encontraram, encontrarão, encontrariam")
[(_, _.lemma_) for _ in tokens]
# Out:
# [(eternamente, 'eternamente'),
#  (crianca, 'crianca'),
#  (b, 'b'),
#  (a, 'o'),
#  (mais, 'mais'),
#  (recente, 'recente'),
#  (versao, 'versao'),
#  (para, 'parir'),
#  (o, 'o'),
#  (cinema, 'cinema'),
#  (da, 'da'),
#  (historia, 'historiar'),
#  (de, 'de'),
#  (peter, 'peter'),
#  (pan, 'pan'),
#  (pretende, 'pretender'),
#  (ser, 'ser'),
#  (tao, 'tao'),
#  (assustadora, 'assustador'),
#  (quanto, 'quantum'),
#  (fascinante, 'fascinante'),
#  (bbr, 'bbr'),
#  (debora, 'debora'),
#  (vicentini, 'vicentini'),
#  (br, 'br'),
#  (ahistoria, 'ahistoria'),
#  (do, 'do'),
#  (menino, 'menino'),
#  (que, 'que'),
#  (nao, 'nao'),
#  (queria, 'querer'),
#  (crescer, 'crescer'),
#  (sempre, 'sempre'),
#  (fascinou, 'fascinar'),
#  (adultos, 'adulto'),
#  (e, 'e'),
#  (criancas, 'criancas'),
#  (no, 'o'),
#  (mundo, 'mundo'),
#  (inteiro, 'inteirar'),
#  (agora, 'agora'),
#  (esses, 'esse'),
#  (fas, 'fas'),
#  (poderao, 'poderao'),
#  (conferir, 'conferir'),
#  (mais, 'mais'),
#  (uma, 'umar'),
#  (versao, 'versao'),
#  (d, 'd'),
#  (essa, 'esse'),
#  (historia, 'historiar'),
#  (magica, 'magico'),
#  (com, 'com'),
#  (o, 'o'),
#  (filme, 'filmar'),
#  (peter, 'peter'),
#  (pan, 'pan'),
#  (que, 'que'),
#  (estreia, 'estrear'),
#  (hoje, 'hoje'),
#  (nos, 'o'),
#  (cinemas, 'cinema'),
#  (capixabas, 'capixabas'),
#  (quem, 'quem'),
#  (acha, 'achar'),
#  (que, 'que'),
#  (peter, 'peter'),
#  (pan, 'pan'),
#  (nao, 'nao'),
#  (e, 'e'),
#  (nada, 'nado'),
#  (mais, 'mais'),
#  (do, 'do'),
#  (que, 'que'),
#  (uma, 'umar'),
#  (fantasia, 'fantasiar'),
#  (infantil, 'infantil'),
#  (sobre, 'sobrar'),
#  (crocodilos, 'crocodilo'),
#  (simpaticos, 'simpaticos'),
#  (fadinhas, 'fadinhas'),
#  (voadoras, 'voador'),
#  (viloes, 'viloes'),
#  (bigodudos, 'bigodudos'),
#  (e, 'e'),
#  (piratas, 'pirata'),
#  (com, 'com'),
#  (ganchos, 'gancho'),
#  (no, 'o'),
#  (lugar, 'lugar'),
#  (de, 'de'),
#  (maos, 'maos'),
#  (deve, 'dever'),
#  (repensar, 'repensar'),
#  (suas, 'suar'),
#  (posicoes, 'posicoes'),
#  (com, 'com'),
#  (essa, 'esse'),
#  (nova, 'novo'),
#  (versao, 'versao'),
#  (que, 'que'),
#  (tem, 'ter'),
#  (roteiro, 'roteiro'),
#  (e, 'e'),
#  (direcao, 'direcao'),
#  (de, 'de'),
#  (pj, 'pj'),
#  (hogan, 'hogan'),
#  (o, 'o'),
#  (casamento, 'casamentar'),
#  (de, 'de'),
#  (muriel, 'muriel'),
#  (a, 'o'),
#  (mais, 'mais'),
#  (recente, 'recente'),
#  (versao, 'versao'),
#  (para, 'parir'),
#  (o, 'o'),
#  (cinema, 'cinema'),
#  (da, 'da'),
#  (historia, 'historiar'),
#  (criada, 'criar'),
#  (ha, 'ha'),
#  (one, 'one'),
#  (hundred, 'hundred'),
#  (anos, 'ano'),
#  (pelo, 'pelar'),
#  (britanico, 'britanico'),
#  (j, 'j'),
#  (m, 'm'),
#  (barrie, 'barrie'),
#  (sobre, 'sobrar'),
#  (um, 'um'),
#  (garoto, 'garotar'),
#  (que, 'que'),
#  (se, 'se'),
#  (recusa, 'recusar'),
#  (a, 'o'),
#  (crescer, 'crescer'),
#  (pretende, 'pretender'),
#  (ser, 'ser'),
#  (tao, 'tao'),
#  (assustadora, 'assustador'),
#  (quanto, 'quantum'),
#  (fascinante, 'fascinante'),
#  (e, 'e'),
#  (alem, 'alar'),
#  (d, 'd'),
#  (isso, 'isso'),
#  (agradar, 'agradar'),
#  (a, 'o'),
#  (todas, 'todo'),
#  (as, 'o'),
#  (idades, 'idade'),
#  (o, 'o'),
#  (novo, 'novo'),
#  (peter, 'peter'),
#  (pan, 'pan'),
#  (e, 'e'),
#  (a, 'o'),
#  (primeira, 'primeiro'),
#  (versao, 'versao'),
#  (moderna, 'moderno'),
#  (da, 'da'),
#  (historia, 'historiar'),
#  (filmada, 'filmar'),
#  (com, 'com'),
#  (personagens, 'personagem'),
#  (de, 'de'),
#  (verdade, 'verdade'),
#  ( , ' '),
#  (o, 'o'),
#  (angelical, 'angelical'),
#  (jeremy, 'jeremy'),
#  (sumpter, 'sumpter'),
#  (de, 'de'),
#  (fourteen, 'fourteen'),
#  (anos, 'ano'),
#  (faz, 'fazer'),
#  (o, 'o'),
#  (papeltitulo, 'papeltitulo'),
#  (o, 'o'),
#  (capitao, 'capitao'),
#  (gancho, 'gancho'),
#  (e, 'e'),
#  (representado, 'representar'),
#  (por, 'por'),
#  (jason, 'jason'),
#  (isaacs, 'isaacs'),
#  (como, 'comer'),
#  (uma, 'umar'),
#  (figura, 'figurar'),
#  (assustadora, 'assustador'),
#  (sem, 'sem'),
#  (aquela, 'aquele'),
#  (mencao, 'mencao'),
#  (comica, 'comica'),
#  (das, 'das'),
#  (versoes, 'versoes'),
#  (anteriores, 'anterior'),
#  (o, 'o'),
#  (mesmo, 'mesmo'),
#  (ator, 'ator'),
#  (tambem, 'tambem'),
#  (faz, 'fazer'),
#  (o, 'o'),
#  (papel, 'papel'),
#  (do, 'do'),
#  (pai, 'pai'),
#  (de, 'de'),
#  (wendy, 'wendy'),
#  (darling, 'darling'),
#  (representada, 'representar'),
#  (pela, 'pelar'),
#  (desconhecida, 'desconhecido'),
#  (atriz, 'atriz'),
#  (britanica, 'britanica'),
#  (rachel, 'rachel'),
#  (hurdwood, 'hurdwood'),
#  (de, 'de'),
#  (thirteen, 'thirteen'),
#  (anos, 'ano'),
#  (wendy, 'wendy'),
#  (e, 'e'),
#  (uma, 'umar'),
#  (uma, 'umar'),
#  (garota, 'garoto'),
#  (que, 'que'),
#  (reluta, 'relutar'),
#  (em, 'em'),
#  (deixar, 'deixar'),
#  (de, 'de'),
#  (ser, 'ser'),
#  (crianca, 'crianca'),
#  (e, 'e'),
#  (que, 'que'),
#  (se, 'se'),
#  (apaixona, 'apaixonar'),
#  (pela, 'pelar'),
#  (primeira, 'primeiro'),
#  (vez, 'vez'),
#  (o, 'o'),
#  (peter, 'peter'),
#  (pan, 'pan'),
#  (criado, 'criar'),
#  (por, 'por'),
#  (hogan, 'hogan'),
#  (tem, 'ter'),
#  (varios, 'varios'),
#  (momentos, 'momento'),
#  (assustadores, 'assustador'),
#  (as, 'o'),
#  (sereias, 'sereia'),
#  (da, 'da'),
#  (terra, 'terra'),
#  (do, 'do'),
#  (nunca, 'nunca'),
#  (que, 'que'),
#  (tentam, 'tentar'),
#  (atrair, 'atrair'),
#  (wendy, 'wendy'),
#  (para, 'parir'),
#  (a, 'o'),
#  (morte, 'morte'),
#  (rapida, 'rapida'),
#  (pelo, 'pelar'),
#  (afogamento, 'afogamento'),
#  (tem, 'ter'),
#  (tao, 'tao'),
#  (pouca, 'pouco'),
#  (semelhanca, 'semelhanca'),
#  (com, 'com'),
#  (a, 'o'),
#  (pequena, 'pequeno'),
#  (sereia, 'sereia'),
#  (da, 'da'),
#  (disney, 'disney'),
#  (quando, 'quando'),
#  (o, 'o'),
#  (capitao, 'capitao'),
#  (gancho, 'gancho'),
#  (tem, 'ter'),
#  (com, 'com'),
#  (um, 'um'),
#  (pai, 'pai'),
#  (amoroso, 'amoroso'),
#  (o, 'o'),
#  (proprio, 'proprio'),
#  (capitao, 'capitao'),
#  (gancho, 'gancho'),
#  (que, 'que'),
#  (em, 'em'),
#  (muitas, 'muito'),
#  (versoes, 'versoes'),
#  (da, 'da'),
#  (historia, 'historiar'),
#  (e, 'e'),
#  (apresentado, 'apresentar'),
#  (como, 'comer'),
#  (figura, 'figurar'),
#  (caricata, 'caricato'),
#  (e, 'e'),
#  (um, 'um'),
#  (louco, 'louco'),
#  (narcisista, 'narcisista'),
#  (que, 'que'),
#  (sen, 'sen'),
#  (te, 'te'),
#  (prazer, 'prazer'),
#  (em, 'em'),
#  (escolher, 'escolher'),
#  (entre, 'entrar'),
#  (os, 'o'),
#  (diversos, 'diverso'),
#  (ganchos, 'gancho'),
#  (de, 'de'),
#  (metal, 'metal'),
#  (aquele, 'aquele'),
#  (que, 'que'),
#  (usara, 'usar'),
#  (a, 'o'),
#  (cada, 'cada'),
#  (dia, 'dia'),
#  (servico, 'servico'),
#  ( , ' '),
#  (filme, 'filmar'),
#  (peter, 'peter'),
#  (pan, 'pan'),
#  ( , ' '),
#  (genero, 'genero'),
#  (aventura, 'aventurar'),
#  ( , ' '),
#  (censura, 'censurar'),
#  (livre, 'livrar'),
#  ( , ' '),
#  (direcao, 'direcao'),
#  (j, 'j'),
#  (p, 'p'),
#  (hogan, 'hogan'),
#  ( , ' '),
#  (elenco, 'elenco'),
#  (jeremy, 'jeremy'),
#  (sumpter, 'sumpter'),
#  (jason, 'jason'),
#  (isaacs, 'isaacs'),
#  ( , ' '),
#  (onde, 'onde'),
#  (ver, 'ver'),
#  (kinoplex, 'kinoplex'),
#  (five, 'five'),
#  (multiplex, 'multiplex'),
#  (laranjeiras, 'laranjeira'),
#  (three, 'three'),
#  (viva, 'vivo'),
#  (cinema, 'cinema'),
#  (one, 'one'),
#  (saiba, 'saber'),
#  (mais, 'mais'),
#  ( , ' '),
#  (jeremy, 'jeremy'),
#  (sumpter, 'sumpter'),
#  (de, 'de'),
#  (a, 'o'),
#  (mao, 'mao'),
#  (do, 'do'),
#  (diabo, 'diabo'),
#  (e, 'e'),
#  (o, 'o'),
#  (unico, 'unico'),
#  (ator, 'ator'),
#  (americano, 'americano'),
#  (no, 'o'),
#  (elenco, 'elenco'),
#  (de, 'de'),
#  (protagonistas, 'protagonista'),
#  (do, 'do'),
#  (filme, 'filmar'),
#  ( , ' '),
#  (jason, 'jason'),
#  (isaacs, 'isaacs'),
#  (ja, 'ja'),
#  (fez, 'fazer'),
#  (trabalhos, 'trabalho'),
#  (como, 'comer'),
#  (o, 'o'),
#  (patriota, 'patriota'),
#  (falcao, 'falcao'),
#  (negro, 'negro'),
#  (em, 'em'),
#  (perigo, 'perigar'),
#  (e, 'e'),
#  (harry, 'harry'),
#  (potter, 'potter'),
#  (e, 'e'),
#  (a, 'o'),
#  (camara, 'camara'),
#  (secreta, 'secreto'),
#  ( , ' '),
#  (o, 'o'),
#  (diretor, 'diretor'),
#  (pjhogan, 'pjhogan'),
#  (coescreveu, 'coescreveu'),
#  (peter, 'peter'),
#  (pan, 'pan'),
#  (com, 'com'),
#  (michael, 'michael'),
#  (goldenberg, 'goldenberg'),
#  (de, 'de'),
#  (contato, 'contato'),
#  ( , ' '),
#  (o, 'o'),
#  (filme, 'filmar'),
#  (foi, 'ser'),
#  (rodado, 'rodar'),
#  (na, 'o'),
#  (australia, 'australia'),
#  ( , ' '),
#  (hogan, 'hogan'),
#  (trabalhou, 'trabalhar'),
#  (nos, 'o'),
#  (bastidores, 'bastidor'),
#  (com, 'com'),
#  (cineastas, 'cineasta'),
#  (australianos, 'australiano'),
#  (como, 'comer'),
#  (o, 'o'),
#  (diretor, 'diretor'),
#  (de, 'de'),
#  (fotografia, 'fotografia'),
#  (donald, 'donald'),
#  (mcalpine, 'mcalpine'),
#  (indicado, 'indicar'),
#  (a, 'o'),
#  (o, 'o'),
#  (oscar, 'oscar'),
#  (com, 'com'),
#  (moulin, 'moulin'),
#  (rouge, 'rouge'),
#  (o, 'o'),
#  (desenhista, 'desenhista'),
#  (de, 'de'),
#  (producao, 'producao'),
#  (roger, 'roger'),
#  (ford, 'ford'),
#  (indicado, 'indicar'),
#  (a, 'o'),
#  (o, 'o'),
#  (oscar, 'oscar'),
#  (com, 'com'),
#  (babe, 'babar'),
#  (e, 'e'),
#  (janet, 'janet'),
#  (patterson, 'patterson'),
#  (indicada, 'indicar'),
#  (a, 'o'),
#  (o, 'o'),
#  (oscar, 'oscar'),
#  (com, 'com'),
#  (o, 'o'),
#  (piano, 'piano'),
#  (retrato, 'retratar'),
#  (de, 'de'),
#  (uma, 'umar'),
#  (mulher, 'mulher'),
#  (e, 'e'),
#  (oscar, 'oscar'),
#  (e, 'e'),
#  (lucinda, 'lucinda'),
#  (brbrhr, 'brbrhr'),
#  (data, 'datar'),
#  (da, 'da'),
#  (publicacao, 'publicacao'),
#  (nine, 'ninar'),
#  (million, 'million'),
#  (,, ','),
#  (twelve, 'twelve'),
#  (thousand, 'thousand'),
#  (and, 'and'),
#  (four, 'four'),
#  ( , ' '),
#  (pagina, 'paginar'),
#  (three, 'three'),
#  (br, 'br'),
#  (editoria, 'editoria'),
#  (at2, 'at2'),
#  (brbr, 'brbr')]

# %%
# Grammatical classes (PoSTagger)
[(_.orth_, _.pos_) for _ in tokens]
# Out:
# [('eternamente', 'ADV'),
#  ('crianca', 'ADV'),
#  ('b', 'PRON'),
#  ('a', 'ADP'),
#  ('mais', 'ADV'),
#  ('recente', 'ADJ'),
#  ('versao', 'NOUN'),
#  ('para', 'ADP'),
#  ('o', 'DET'),
#  ('cinema', 'NOUN'),
#  ('da', 'ADP'),
#  ('historia', 'NOUN'),
#  ('de', 'ADP'),
#  ('peter', 'VERB'),
#  ('pan', 'PUNCT'),
#  ('pretende', 'VERB'),
#  ('ser', 'VERB'),
#  ('tao', 'ADV'),
#  ('assustadora', 'ADV'),
#  ('quanto', 'DET'),
#  ('fascinante', 'ADJ'),
#  ('bbr', 'ADJ'),
#  ('debora', 'ADJ'),
#  ('vicentini', 'X'),
#  ('br', 'ADJ'),
#  ('ahistoria', 'VERB'),
#  ('do', 'ADP'),
#  ('menino', 'NOUN'),
#  ('que', 'PRON'),
#  ('nao', 'ADV'),
#  ('queria', 'VERB'),
#  ('crescer', 'VERB'),
#  ('sempre', 'ADV'),
#  ('fascinou', 'VERB'),
#  ('adultos', 'NOUN'),
#  ('e', 'CCONJ'),
#  ('criancas', 'ADJ'),
#  ('no', 'PRON'),
#  ('mundo', 'NOUN'),
#  ('inteiro', 'ADJ'),
#  ('agora', 'ADV'),
#  ('esses', 'DET'),
#  ('fas', 'NOUN'),
#  ('poderao', 'VERB'),
#  ('conferir', 'VERB'),
#  ('mais', 'ADV'),
#  ('uma', 'NUM'),
#  ('versao', 'NOUN'),
#  ('d', 'ADP'),
#  ('essa', 'DET'),
#  ('historia', 'NOUN'),
#  ('magica', 'ADJ'),
#  ('com', 'ADP'),
#  ('o', 'DET'),
#  ('filme', 'NOUN'),
#  ('peter', 'ADJ'),
#  ('pan', 'ADP'),
#  ('que', 'PRON'),
#  ('estreia', 'VERB'),
#  ('hoje', 'ADV'),
#  ('nos', 'PRON'),
#  ('cinemas', 'NOUN'),
#  ('capixabas', 'NOUN'),
#  ('quem', 'PRON'),
#  ('acha', 'VERB'),
#  ('que', 'SCONJ'),
#  ('peter', 'VERB'),
#  ('pan', 'ADJ'),
#  ('nao', 'ADJ'),
#  ('e', 'CCONJ'),
#  ('nada', 'PRON'),
#  ('mais', 'ADV'),
#  ('do', 'ADV'),
#  ('que', 'ADP'),
#  ('uma', 'DET'),
#  ('fantasia', 'NOUN'),
#  ('infantil', 'ADJ'),
#  ('sobre', 'ADP'),
#  ('crocodilos', 'NOUN'),
#  ('simpaticos', 'ADJ'),
#  ('fadinhas', 'ADJ'),
#  ('voadoras', 'ADV'),
#  ('viloes', 'NOUN'),
#  ('bigodudos', 'X'),
#  ('e', 'CCONJ'),
#  ('piratas', 'NOUN'),
#  ('com', 'ADP'),
#  ('ganchos', 'NOUN'),
#  ('no', 'X'),
#  ('lugar', 'NOUN'),
#  ('de', 'ADP'),
#  ('maos', 'NOUN'),
#  ('deve', 'AUX'),
#  ('repensar', 'VERB'),
#  ('suas', 'DET'),
#  ('posicoes', 'NOUN'),
#  ('com', 'ADP'),
#  ('essa', 'DET'),
#  ('nova', 'ADJ'),
#  ('versao', 'NOUN'),
#  ('que', 'PRON'),
#  ('tem', 'VERB'),
#  ('roteiro', 'NOUN'),
#  ('e', 'CCONJ'),
#  ('direcao', 'NOUN'),
#  ('de', 'ADP'),
#  ('pj', 'PROPN'),
#  ('hogan', 'NOUN'),
#  ('o', 'DET'),
#  ('casamento', 'NOUN'),
#  ('de', 'ADP'),
#  ('muriel', 'NOUN'),
#  ('a', 'DET'),
#  ('mais', 'ADV'),
#  ('recente', 'ADJ'),
#  ('versao', 'NOUN'),
#  ('para', 'ADP'),
#  ('o', 'DET'),
#  ('cinema', 'NOUN'),
#  ('da', 'ADP'),
#  ('historia', 'NOUN'),
#  ('criada', 'VERB'),
#  ('ha', 'NOUN'),
#  ('one', 'X'),
#  ('hundred', 'X'),
#  ('anos', 'NOUN'),
#  ('pelo', 'ADV'),
#  ('britanico', 'ADJ'),
#  ('j', 'ADP'),
#  ('m', 'DET'),
#  ('barrie', 'VERB'),
#  ('sobre', 'ADP'),
#  ('um', 'DET'),
#  ('garoto', 'NOUN'),
#  ('que', 'PRON'),
#  ('se', 'PRON'),
#  ('recusa', 'VERB'),
#  ('a', 'ADP'),
#  ('crescer', 'VERB'),
#  ('pretende', 'VERB'),
#  ('ser', 'VERB'),
#  ('tao', 'ADV'),
#  ('assustadora', 'ADV'),
#  ('quanto', 'DET'),
#  ('fascinante', 'ADJ'),
#  ('e', 'PUNCT'),
#  ('alem', 'VERB'),
#  ('d', 'ADP'),
#  ('isso', 'PRON'),
#  ('agradar', 'VERB'),
#  ('a', 'ADP'),
#  ('todas', 'DET'),
#  ('as', 'DET'),
#  ('idades', 'NOUN'),
#  ('o', 'DET'),
#  ('novo', 'ADJ'),
#  ('peter', 'VERB'),
#  ('pan', 'PRON'),
#  ('e', 'CCONJ'),
#  ('a', 'DET'),
#  ('primeira', 'ADJ'),
#  ('versao', 'NOUN'),
#  ('moderna', 'ADJ'),
#  ('da', 'ADP'),
#  ('historia', 'NOUN'),
#  ('filmada', 'VERB'),
#  ('com', 'ADP'),
#  ('personagens', 'NOUN'),
#  ('de', 'ADP'),
#  ('verdade', 'NOUN'),
#  (' ', 'SPACE'),
#  ('o', 'DET'),
#  ('angelical', 'NOUN'),
#  ('jeremy', 'VERB'),
#  ('sumpter', 'VERB'),
#  ('de', 'ADP'),
#  ('fourteen', 'NOUN'),
#  ('anos', 'ADJ'),
#  ('faz', 'VERB'),
#  ('o', 'DET'),
#  ('papeltitulo', 'NOUN'),
#  ('o', 'DET'),
#  ('capitao', 'NOUN'),
#  ('gancho', 'NOUN'),
#  ('e', 'CCONJ'),
#  ('representado', 'VERB'),
#  ('por', 'ADP'),
#  ('jason', 'NOUN'),
#  ('isaacs', 'ADJ'),
#  ('como', 'ADP'),
#  ('uma', 'DET'),
#  ('figura', 'NOUN'),
#  ('assustadora', 'ADJ'),
#  ('sem', 'ADP'),
#  ('aquela', 'DET'),
#  ('mencao', 'NOUN'),
#  ('comica', 'ADJ'),
#  ('das', 'VERB'),
#  ('versoes', 'NOUN'),
#  ('anteriores', 'ADJ'),
#  ('o', 'DET'),
#  ('mesmo', 'DET'),
#  ('ator', 'NOUN'),
#  ('tambem', 'VERB'),
#  ('faz', 'VERB'),
#  ('o', 'DET'),
#  ('papel', 'NOUN'),
#  ('do', 'ADP'),
#  ('pai', 'NOUN'),
#  ('de', 'ADP'),
#  ('wendy', 'NOUN'),
#  ('darling', 'ADJ'),
#  ('representada', 'VERB'),
#  ('pela', 'DET'),
#  ('desconhecida', 'VERB'),
#  ('atriz', 'NOUN'),
#  ('britanica', 'ADJ'),
#  ('rachel', 'X'),
#  ('hurdwood', 'ADJ'),
#  ('de', 'ADP'),
#  ('thirteen', 'NOUN'),
#  ('anos', 'ADJ'),
#  ('wendy', 'NOUN'),
#  ('e', 'CCONJ'),
#  ('uma', 'DET'),
#  ('uma', 'DET'),
#  ('garota', 'NOUN'),
#  ('que', 'PRON'),
#  ('reluta', 'VERB'),
#  ('em', 'ADP'),
#  ('deixar', 'AUX'),
#  ('de', 'ADP'),
#  ('ser', 'VERB'),
#  ('crianca', 'NOUN'),
#  ('e', 'CCONJ'),
#  ('que', 'PRON'),
#  ('se', 'PRON'),
#  ('apaixona', 'VERB'),
#  ('pela', 'NOUN'),
#  ('primeira', 'ADP'),
#  ('vez', 'NOUN'),
#  ('o', 'DET'),
#  ('peter', 'NOUN'),
#  ('pan', 'AUX'),
#  ('criado', 'VERB'),
#  ('por', 'ADP'),
#  ('hogan', 'NOUN'),
#  ('tem', 'VERB'),
#  ('varios', 'NOUN'),
#  ('momentos', 'NOUN'),
#  ('assustadores', 'ADJ'),
#  ('as', 'DET'),
#  ('sereias', 'NOUN'),
#  ('da', 'ADP'),
#  ('terra', 'NOUN'),
#  ('do', 'ADV'),
#  ('nunca', 'ADV'),
#  ('que', 'PRON'),
#  ('tentam', 'VERB'),
#  ('atrair', 'VERB'),
#  ('wendy', 'NOUN'),
#  ('para', 'ADP'),
#  ('a', 'DET'),
#  ('morte', 'NOUN'),
#  ('rapida', 'VERB'),
#  ('pelo', 'ADJ'),
#  ('afogamento', 'NOUN'),
#  ('tem', 'VERB'),
#  ('tao', 'VERB'),
#  ('pouca', 'DET'),
#  ('semelhanca', 'NOUN'),
#  ('com', 'ADP'),
#  ('a', 'DET'),
#  ('pequena', 'ADJ'),
#  ('sereia', 'NOUN'),
#  ('da', 'ADP'),
#  ('disney', 'ADJ'),
#  ('quando', 'ADV'),
#  ('o', 'DET'),
#  ('capitao', 'NOUN'),
#  ('gancho', 'NOUN'),
#  ('tem', 'VERB'),
#  ('com', 'ADP'),
#  ('um', 'DET'),
#  ('pai', 'NOUN'),
#  ('amoroso', 'ADJ'),
#  ('o', 'DET'),
#  ('proprio', 'NOUN'),
#  ('capitao', 'ADJ'),
#  ('gancho', 'NOUN'),
#  ('que', 'PRON'),
#  ('em', 'ADP'),
#  ('muitas', 'DET'),
#  ('versoes', 'NOUN'),
#  ('da', 'ADP'),
#  ('historia', 'NOUN'),
#  ('e', 'CCONJ'),
#  ('apresentado', 'VERB'),
#  ('como', 'ADP'),
#  ('figura', 'NOUN'),
#  ('caricata', 'ADJ'),
#  ('e', 'CCONJ'),
#  ('um', 'DET'),
#  ('louco', 'NOUN'),
#  ('narcisista', 'ADJ'),
#  ('que', 'PRON'),
#  ('sen', 'ADV'),
#  ('te', 'PRON'),
#  ('prazer', 'NOUN'),
#  ('em', 'ADP'),
#  ('escolher', 'VERB'),
#  ('entre', 'ADP'),
#  ('os', 'DET'),
#  ('diversos', 'ADJ'),
#  ('ganchos', 'SYM'),
#  ('de', 'ADP'),
#  ('metal', 'NOUN'),
#  ('aquele', 'X'),
#  ('que', 'PRON'),
#  ('usara', 'VERB'),
#  ('a', 'ADP'),
#  ('cada', 'DET'),
#  ('dia', 'NOUN'),
#  ('servico', 'ADJ'),
#  (' ', 'SPACE'),
#  ('filme', 'NOUN'),
#  ('peter', 'ADJ'),
#  ('pan', 'ADP'),
#  (' ', 'SPACE'),
#  ('genero', 'NOUN'),
#  ('aventura', 'VERB'),
#  (' ', 'SPACE'),
#  ('censura', 'NOUN'),
#  ('livre', 'ADJ'),
#  (' ', 'SPACE'),
#  ('direcao', 'VERB'),
#  ('j', 'CCONJ'),
#  ('p', 'DET'),
#  ('hogan', 'VERB'),
#  (' ', 'SPACE'),
#  ('elenco', 'NOUN'),
#  ('jeremy', 'X'),
#  ('sumpter', 'VERB'),
#  ('jason', 'NOUN'),
#  ('isaacs', 'ADJ'),
#  (' ', 'SPACE'),
#  ('onde', 'ADV'),
#  ('ver', 'VERB'),
#  ('kinoplex', 'NOUN'),
#  ('five', 'NOUN'),
#  ('multiplex', 'ADJ'),
#  ('laranjeiras', 'NOUN'),
#  ('three', 'ADJ'),
#  ('viva', 'ADJ'),
#  ('cinema', 'ADJ'),
#  ('one', 'ADJ'),
#  ('saiba', 'VERB'),
#  ('mais', 'ADV'),
#  (' ', 'SPACE'),
#  ('jeremy', 'VERB'),
#  ('sumpter', 'VERB'),
#  ('de', 'ADP'),
#  ('a', 'DET'),
#  ('mao', 'NOUN'),
#  ('do', 'DET'),
#  ('diabo', 'NOUN'),
#  ('e', 'CCONJ'),
#  ('o', 'DET'),
#  ('unico', 'ADJ'),
#  ('ator', 'NOUN'),
#  ('americano', 'ADJ'),
#  ('no', 'DET'),
#  ('elenco', 'NOUN'),
#  ('de', 'ADP'),
#  ('protagonistas', 'NOUN'),
#  ('do', 'ADP'),
#  ('filme', 'NOUN'),
#  (' ', 'SPACE'),
#  ('jason', 'ADJ'),
#  ('isaacs', 'ADJ'),
#  ('ja', 'ADP'),
#  ('fez', 'VERB'),
#  ('trabalhos', 'NOUN'),
#  ('como', 'ADP'),
#  ('o', 'DET'),
#  ('patriota', 'NOUN'),
#  ('falcao', 'ADJ'),
#  ('negro', 'X'),
#  ('em', 'ADP'),
#  ('perigo', 'NOUN'),
#  ('e', 'CCONJ'),
#  ('harry', 'NOUN'),
#  ('potter', 'NOUN'),
#  ('e', 'CCONJ'),
#  ('a', 'DET'),
#  ('camara', 'NOUN'),
#  ('secreta', 'ADJ'),
#  (' ', 'SPACE'),
#  ('o', 'DET'),
#  ('diretor', 'NOUN'),
#  ('pjhogan', 'AUX'),
#  ('coescreveu', 'VERB'),
#  ('peter', 'VERB'),
#  ('pan', 'ADP'),
#  ('com', 'ADP'),
#  ('michael', 'NOUN'),
#  ('goldenberg', 'NOUN'),
#  ('de', 'ADP'),
#  ('contato', 'NOUN'),
#  (' ', 'SPACE'),
#  ('o', 'DET'),
#  ('filme', 'NOUN'),
#  ('foi', 'AUX'),
#  ('rodado', 'VERB'),
#  ('na', 'DET'),
#  ('australia', 'VERB'),
#  (' ', 'SPACE'),
#  ('hogan', 'NOUN'),
#  ('trabalhou', 'VERB'),
#  ('nos', 'PRON'),
#  ('bastidores', 'SYM'),
#  ('com', 'ADP'),
#  ('cineastas', 'NOUN'),
#  ('australianos', 'ADJ'),
#  ('como', 'ADP'),
#  ('o', 'DET'),
#  ('diretor', 'NOUN'),
#  ('de', 'ADP'),
#  ('fotografia', 'NOUN'),
#  ('donald', 'X'),
#  ('mcalpine', 'ADJ'),
#  ('indicado', 'VERB'),
#  ('a', 'ADP'),
#  ('o', 'DET'),
#  ('oscar', 'VERB'),
#  ('com', 'ADP'),
#  ('moulin', 'NOUN'),
#  ('rouge', 'X'),
#  ('o', 'DET'),
#  ('desenhista', 'NOUN'),
#  ('de', 'ADP'),
#  ('producao', 'NOUN'),
#  ('roger', 'VERB'),
#  ('ford', 'NOUN'),
#  ('indicado', 'VERB'),
#  ('a', 'ADP'),
#  ('o', 'DET'),
#  ('oscar', 'VERB'),
#  ('com', 'ADP'),
#  ('babe', 'NOUN'),
#  ('e', 'CCONJ'),
#  ('janet', 'NOUN'),
#  ('patterson', 'ADJ'),
#  ('indicada', 'VERB'),
#  ('a', 'ADP'),
#  ('o', 'DET'),
#  ('oscar', 'VERB'),
#  ('com', 'ADP'),
#  ('o', 'DET'),
#  ('piano', 'NOUN'),
#  ('retrato', 'ADJ'),
#  ('de', 'ADP'),
#  ('uma', 'DET'),
#  ('mulher', 'NOUN'),
#  ('e', 'CCONJ'),
#  ('oscar', 'VERB'),
#  ('e', 'CCONJ'),
#  ('lucinda', 'VERB'),
#  ('brbrhr', 'VERB'),
#  ('data', 'NOUN'),
#  ('da', 'ADP'),
#  ('publicacao', 'X'),
#  ('nine', 'X'),
#  ('million', 'ADJ'),
#  (',', 'PUNCT'),
#  ('twelve', 'NOUN'),
#  ('thousand', 'NOUN'),
#  ('and', 'PROPN'),
#  ('four', 'X'),
#  (' ', 'SPACE'),
#  ('pagina', 'ADJ'),
#  ('three', 'ADJ'),
#  ('br', 'ADJ'),
#  ('editoria', 'ADJ'),
#  ('at2', 'NOUN'),
#  ('brbr', 'ADJ')]

# %% [markdown]
# ### Others analyzes

# %%
# Similatiry between words
# print(f"Tokens: [{tokens[0]}][{tokens[1]}] : "
#       f"similarity[{tokens[0].similarity(tokens[1])}]")

# print(f"Tokens: [{tokens[12]}][{tokens[14]}] : "
#       f"similarity[{tokens[12].similarity(tokens[14])}]")

# print(f"Tokens: [{tokens[16]}][{tokens[17]}] : "
#       f"similarity[{tokens[16].similarity(tokens[17])}]")

# print(f"Tokens: [{tokens[16]}][{tokens[1]}] : "
#       f"similarity[{tokens[16].similarity(tokens[1])}]")

# %%
# Check ancestor of words
# aux = nlp(u"encontrar encontrei")
# aux_tk = [_ for _ in aux]
# aux_tk[0].is_ancestor(aux_tk[1])

# tokens[0].is_ancestor(tokens[1])

# %%
# Getting entities
# aux = nlp(u'Machado de Assis um dos melhores escritores do Brasil, foi o primeiro presidente da Academia Brasileira de Letras')

# [(_, _.label_) for _ in aux.ents]
# [(_, _.label_) for _ in doc.ents]

# %% [markdown]
# ---
